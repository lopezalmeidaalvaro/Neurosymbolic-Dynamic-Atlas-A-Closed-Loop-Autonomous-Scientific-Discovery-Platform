# %% [markdown]
# # Space Telemetry Preprocessing and Thermodynamic Validation
# This notebook runs thermodynamic range and derivative invariant checks on NASA flight telemetry datasets.

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('..'))
from real_telemetry_pipeline.dataset_preprocessing import validate_space_telemetry

# Validate raw NASA ATCS telemetry
csv_path = os.path.join('..', 'datasets', 'nasa_atcs_telemetry.csv')
validate_space_telemetry(csv_path)
